# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def load_post_factchecks():
    posts_factchecks = pd.read_excel('../../../data/1-factechecks/1-posts_factchecks/factchekers_check.xlsx').drop('Unnamed: 0', axis = 1)[['id_factcheck', 
                 'post_factcheck', 
                 'date_factcheck_facebook']].rename(columns = {'post_factcheck':'link_post_factcheck'})
    
    africa_posts = pd.read_excel('../../../data/1-factechecks/1-posts_factchecks/africacheck_matches.xlsx')
    africa_posts[africa_posts['no_socialmedia_factcheck'] == 0]
    
    africa_posts['post_factcheck'] = None
    africa_posts = africa_posts.drop('Unnamed: 0', axis = 1)[['id_factcheck', 
                 'post_factcheck', 
                 'date_factcheck_facebook']].rename(columns = {'post_factcheck':'link_post_factcheck'})
    africa_posts = africa_posts[list(posts_factchecks.columns)]
    africa_posts = africa_posts[~africa_posts['date_factcheck_facebook'].isna()]
    all_posts = pd.concat([posts_factchecks, africa_posts])
    all_posts = all_posts.dropna()
    return(all_posts)

# %% [markdown]
# ## Load and Merge Data

# %%
posts = load_post_factchecks()
factchecks = pd.read_excel('../../../data/1-factechecks/0-factchecks/factchecks.xlsx')

# %%
pd.merge(left = factchecks, 
        right = posts, 
        on = 'id_factcheck', 
        how = 'left')
# Out:
#       Unnamed: 0                          id_factcheck  organizacion    pais  \
# 0              0  2c51a443-dcfe-3fdc-b901-79566bb18dd0   larepublica    peru
# 1              1  1718b0ab-d593-3704-a78a-bb095d6ecb14   larepublica    peru
# 2              2  3c167832-8e73-330a-ab8a-19b219f79dfc   larepublica    peru
# 3              3  656ae72f-a364-353d-813a-dd24472479a6   larepublica    peru
# 4              4  6fcce096-cf30-3f7c-ae86-591590d024e6   larepublica    peru
# ...          ...                                   ...           ...     ...
# 4145         539  68cfebae-1201-388f-9a08-3e128cabefd4  africa_check  africa
# 4146         540  49d7af65-82b9-3493-a672-ed225bac8b5d  africa_check  africa
# 4147         541  5ed4a06f-f695-3b6c-9ebe-af5cffd5b05d  africa_check  africa
# 4148         542  5c1725d5-3f40-3277-9c1b-6bfc27d21bb9  africa_check  africa
# 4149         543  352681e4-dff5-3dea-b07a-7a5c75875778  africa_check  africa
#
#                                          titulo_chequeo        fecha_chequeo  \
# 0     cafe haiti es falso que el cafe haiti de miraf...  2020-05-08 00:00:00
# 1     areas de aislamiento es falsa la publicacion d...  2020-05-08 00:00:00
# 2     dioxido de cloro es imprecisa la publicacion d...  2020-04-08 00:00:00
# 3     5g es falso que foto es de vacuna china con ar...  2020-03-08 00:00:00
# 4     coronavirus es impreciso afirmar que colegio m...  2020-03-08 00:00:00
# ...                                                 ...                  ...
# 4145    anc and da both wrong gap between rich and poor  2012-11-07 00:00:00
# 4146  flawed data undermines sa claims vaccination c...  2012-11-21 00:00:00
# 4147  zille says cape town rich poor divide narrowes...  2012-12-03 00:00:00
# 4148  did gun control cause fall gun crime data back...  2012-12-15 00:00:00
# 4149  fact checking president kenyatta kenyas small ...  2020-03-03 00:00:00
#
#                                            link_chequeo  \
# 0     https://larepublica.pe/verificador/2020/08/05/...
# 1     https://larepublica.pe/verificador/2020/08/05/...
# 2     https://larepublica.pe/verificador/2020/08/04/...
# 3     https://larepublica.pe/verificador/2020/08/03/...
# 4     https://larepublica.pe/verificador/2020/08/03/...
# ...                                                 ...
# 4145  https://africacheck.org/fact-checks/reports/an...
# 4146  https://africacheck.org/fact-checks/reports/fl...
# 4147  https://africacheck.org/fact-checks/reports/zi...
# 4148  https://africacheck.org/fact-checks/reports/di...
# 4149  https://africacheck.org/fact-checks/reports/fa...
#
#                          id_desinformacion facebook_partnership_date  \
# 0                                      NaN                2020-06-01
# 1                                      NaN                2020-06-01
# 2                                      NaN                2020-06-01
# 3                                      NaN                2020-06-01
# 4                                      NaN                2020-06-01
# ...                                    ...                       ...
# 4145  3f567287-93f1-3d2b-8ffd-25d198b17ab8                2019-08-15
# 4146  21b05bc4-4a90-3c8a-9abe-4d687757c4f6                2019-08-15
# 4147  0f7906d0-f6e4-3de6-806c-3f5ce130322b                2019-08-15
# 4148  8715caa4-2a02-3987-ab98-0c8e2a934736                2019-08-15
# 4149  bf32f688-5513-3990-b1ff-4ca22c216b8e                2019-08-15
#
#       facebook_partnership link_post_factcheck date_factcheck_facebook
# 0                        1                 NaN                     NaN
# 1                        1                 NaN                     NaN
# 2                        1                 NaN                     NaN
# 3                        1                 NaN                     NaN
# 4                        1                 NaN                     NaN
# ...                    ...                 ...                     ...
# 4145                     1                 NaN                     NaN
# 4146                     1                 NaN                     NaN
# 4147                     1                 NaN                     NaN
# 4148                     1                 NaN                     NaN
# 4149                     1                 NaN                     NaN
#
# [4150 rows x 12 columns]

# %%
factchecks
# Out:
#       Unnamed: 0                            id_chequeo  organizacion    pais  \
# 0              0  2c51a443-dcfe-3fdc-b901-79566bb18dd0   larepublica    peru
# 1              1  1718b0ab-d593-3704-a78a-bb095d6ecb14   larepublica    peru
# 2              2  3c167832-8e73-330a-ab8a-19b219f79dfc   larepublica    peru
# 3              3  656ae72f-a364-353d-813a-dd24472479a6   larepublica    peru
# 4              4  6fcce096-cf30-3f7c-ae86-591590d024e6   larepublica    peru
# ...          ...                                   ...           ...     ...
# 4134         539  68cfebae-1201-388f-9a08-3e128cabefd4  africa_check  africa
# 4135         540  49d7af65-82b9-3493-a672-ed225bac8b5d  africa_check  africa
# 4136         541  5ed4a06f-f695-3b6c-9ebe-af5cffd5b05d  africa_check  africa
# 4137         542  5c1725d5-3f40-3277-9c1b-6bfc27d21bb9  africa_check  africa
# 4138         543  352681e4-dff5-3dea-b07a-7a5c75875778  africa_check  africa
#
#                                          titulo_chequeo        fecha_chequeo  \
# 0     cafe haiti es falso que el cafe haiti de miraf...  2020-05-08 00:00:00
# 1     areas de aislamiento es falsa la publicacion d...  2020-05-08 00:00:00
# 2     dioxido de cloro es imprecisa la publicacion d...  2020-04-08 00:00:00
# 3     5g es falso que foto es de vacuna china con ar...  2020-03-08 00:00:00
# 4     coronavirus es impreciso afirmar que colegio m...  2020-03-08 00:00:00
# ...                                                 ...                  ...
# 4134    anc and da both wrong gap between rich and poor  2012-11-07 00:00:00
# 4135  flawed data undermines sa claims vaccination c...  2012-11-21 00:00:00
# 4136  zille says cape town rich poor divide narrowes...  2012-12-03 00:00:00
# 4137  did gun control cause fall gun crime data back...  2012-12-15 00:00:00
# 4138  fact checking president kenyatta kenyas small ...  2020-03-03 00:00:00
#
#                                            link_chequeo  \
# 0     https://larepublica.pe/verificador/2020/08/05/...
# 1     https://larepublica.pe/verificador/2020/08/05/...
# 2     https://larepublica.pe/verificador/2020/08/04/...
# 3     https://larepublica.pe/verificador/2020/08/03/...
# 4     https://larepublica.pe/verificador/2020/08/03/...
# ...                                                 ...
# 4134  https://africacheck.org/fact-checks/reports/an...
# 4135  https://africacheck.org/fact-checks/reports/fl...
# 4136  https://africacheck.org/fact-checks/reports/zi...
# 4137  https://africacheck.org/fact-checks/reports/di...
# 4138  https://africacheck.org/fact-checks/reports/fa...
#
#                          id_desinformacion facebook_partnership_date  \
# 0                                      NaN                2020-06-01
# 1                                      NaN                2020-06-01
# 2                                      NaN                2020-06-01
# 3                                      NaN                2020-06-01
# 4                                      NaN                2020-06-01
# ...                                    ...                       ...
# 4134  3f567287-93f1-3d2b-8ffd-25d198b17ab8                2019-08-15
# 4135  21b05bc4-4a90-3c8a-9abe-4d687757c4f6                2019-08-15
# 4136  0f7906d0-f6e4-3de6-806c-3f5ce130322b                2019-08-15
# 4137  8715caa4-2a02-3987-ab98-0c8e2a934736                2019-08-15
# 4138  bf32f688-5513-3990-b1ff-4ca22c216b8e                2019-08-15
#
#       facebook_partnership
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 4134                     1
# 4135                     1
# 4136                     1
# 4137                     1
# 4138                     1
#
# [4139 rows x 10 columns]
